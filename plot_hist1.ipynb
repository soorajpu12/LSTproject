# %% [markdown]
# <a href="https://colab.research.google.com/github/soorajpu12/LSTproject/blob/master/plot_hist1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.stats import norm

# %% [markdown]
# ## Histograms from csv

# %%
filepath1 = '/content/ee-chart (46).csv'
df1 = pd.read_csv(filepath1)
df1.head()
# Out:
#    Band Value  LST-Qin 2015 Count
# 0       9.875                 1.0
# 1      10.000                 NaN
# 2      10.125                 NaN
# 3      10.250                 NaN
# 4      10.375                 NaN

# %%
x1 = 'LST-Qin 2015 Count'
x2 = 'Band Value'
ax = df1.plot.bar(x2,x1) # in some plots, you may have to change xlim and ylim

# %% [markdown]
# ## Plot multiple figures

# %%
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 2
rows = 4
for i in range(1, columns*rows +1):
    img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()
